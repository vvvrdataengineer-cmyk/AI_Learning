# %% [markdown]
# **AI Fundamentals:**
#
# **will understand what AI is and how it works, but more importantly, you'll know which tasks AI can help you with and how to work with it effectively and safely.**

# %% [markdown]
# **Use Case: Read multiple PDF into consistent format.**
#
# **Manually:**
#
# - manually review each PDF, copy-paste data into a spreadsheet, and spend hours organizing everything into a consistent format.
#
# **Steps how AI transforms:**
# 1. Upload PDF documents: Specify fields you need.
# 2. AI reads each document and extracts relevant data points automatically.
# 3. AI organizes everything into a clean spreadsheet.
# 4. Review the consolidated data.

# %% [markdown]
# **What is AI?**
#
# **Artificial intelligence is technology that allows computers to do these kinds of tasks that would normally require human intelligence. **
#
# **Replicating intelligent behavior that humans typically do.**
#
# **Computer systems that perform tasks typically associated with human intelligence, such as learning, reasoning, and decision-making**
#
# **AI has been around for many years and is already integrated into many systems we use daily**
# -

# %% [markdown]
# **Our first example is spam detection in your email.**
# **Google Maps arrival time predictions.**
